# %%
import requests, xlrd, xlwt

# %%
#Décima Primeira parte do dataset_Tweet_Sent_BR

# %%
LANG = 'pt'
APIKEY = 'YOUR API KEY'
APIURL = 'https://sentic.net/api/' + LANG + '/' + APIKEY + '.py?text='
FILENAME = 'Tweet_Sent_Br_11'

# %%
wb = xlrd.open_workbook(FILENAME + '.xls')
sheet = wb.sheet_by_index(0)
new_wb = xlwt.Workbook()
new_sheet = new_wb.add_sheet('labeled')

count = 0
for row in range(sheet.nrows):
    text = sheet.cell_value(row, 0)
    for c in [';', '&', '#', '{', '}']: text = text.replace(c, ':')
    label = str(requests.get(APIURL + text).content)[2:-3]
    new_sheet.write(count, 0, text)
    if label == 'NEGATIVE': 
        new_sheet.write(count, 1, label, xlwt.easyxf('font: color red; align: horiz center'))
        print(text + ': \033[91m' + label + '\033[0;0m')
    elif label == 'POSITIVE':
        new_sheet.write(count, 1, label, xlwt.easyxf('font: color green; align: horiz center'))
        print(text + ': \033[92m' + label + '\033[0;0m')
    else:
        new_sheet.write(count, 1, label, xlwt.easyxf('align: horiz center'))
        print(text + ': ' + label)
    count += 1
    
new_wb.save(FILENAME + '_labeled.xls')
# Out:
# OU   DaniloGentili PARA DE SE METER A TRETA É DELE SEU ARROMBADO!  diguinhocoruja s2s2s2  TheNoite: POSITIVE
# Como é linda esta Viviane Pasmanter!   MaisVoce: NEGATIVE
# que lindo o filho do serginho aaaa tão fofinho  altashoras: NEGATIVE
# Esse episódio foi sensacional , Ana Luisa mandando ver *_*  MasterChefBR: POSITIVE
# Tratamos o tema de forma lúdica, alcançando públicos diversos, ong's, orfanatos, igrejas, escolas, teatros, praças  encontro  abusoinfantil: NEGATIVE
# O  MChefLeonardo já fala dms, a produção ainda gosta de tacar lenha na fogueira  Mas te entendo, Léo, sou bem parecido,até   MasterChefBR: NEGATIVE
# Amo esse Douglas  masterchefbr: POSITIVE
# Já estava indo dormir quando o  altashoras  começou com  EoTchanOficial haha não aguentei e já fui logo segurar o tchamm. Tutututupaaaaaa : POSITIVE
# Esse  otacosta é muito canastrão  VideoShowAoVivo: NEUTRAL
#  MasterChefBR AAAAAAAAAAAAAAA EITA SENHOR: NEGATIVE
# Perdemos Chico Xavier pela segunda vez Vá com Deus Nelson Xavier  Encontro: NEGATIVE
# Yuko gente como a gente, queria usar o pênis, ficou duro, decepcionou, pensou em fazer picadinho do pênis mas deixou pra lá  MasterChefBR: NEGATIVE
# Fátima arrasando no  VideoShowAoVivo Maravilhosa!: POSITIVE
# Esse loiro ,que está no programa do  thenoite . Não seria o ator principal , da serie Filhos da anarquia -Jax?: <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">\n<html><head>\n<title>500 Internal Server Error</title>\n</head><body>\n<h1>Internal Server Error</h1>\n<p>The server encountered an internal error or\nmisconfiguration and was unable to complete\nyour request.</p>\n<p>Please contact the server administrator,\n and inform them of the time the error occurred,\nand anything you might have done that may have\ncaused the error.</p>\n<p>More information about this error may be available\nin the server error log.</p>\n</body></html>
#  Shippando_Tudin Não sendo abóbora a galera deveria cair matando hahPasmanterEPivaNoMaisVoce MaisVoce: NEGATIVE
# Chorando com a homenagem do  oserginho para a mãe, dona Ana. Que lindo!    AltasHoras: POSITIVE
# Alguém querendo uma super caneca de unicórnio? Ésó encomendar! Contato na bio!  MaisVoce: NEGATIVE
#  MaiaraeMaraisa ESTOU ANSIOSA    MaiaraeMaraisaNoBial  ConversaComBial: NEUTRAL
# E vamos de  MasterChefBr: NEUTRAL
# Sardinha tem espinha pra caramba cara  MasterChefBR: POSITIVE
#  MaisVoce eu quero essa roupa de unicórnio  : POSITIVE
# Fogaça está mascando chiclete ao vivo e eu adoraria ver a cara do diretor e do produtor vendo isso  MasterChefBR: NEGATIVE
# Pirão no pará e sagrado  valter arrazou  MasterChefBR: POSITIVE
# Sobre essa pessoa q se diz padre, eh melhor eu ficar quietinho, sabe...  ConversaComBial: NEGATIVE
#  BlogDoPim Poderiam repetir aquela célebre entrevista do Bial com o professor  OdeCarvalho realizada nos anos 90  ConversaComBial: POSITIVE
# Chorando até amanhã com:Quem sabe dança Quem não sabe ... TheNoite: POSITIVE
# Fui assaltada nesse mês mas fiz backup na nuvem recuperei todas as fotos, os contatos no email e o número na operadora   Encontro  BACKUP: POSITIVE
# Me acabando de rir com  MaisVoce. Vcs estão demais hj. Kkkkk: NEGATIVE
#  MaisVoce falando que é descontado FGTS do pagamento. Pelo amor de Deus. Fgts não é descontado. é obrigação da empresa recolher.: POSITIVE
# UFA!  AltasHoras começou!Pra salvar a noite.: POSITIVE
#  TheNoite sem duvidas eh o melhor programa da TV, gentili eh foda demais.: POSITIVE
# Eu só queria as comidinhas de ontem do  MasterChefBR: POSITIVE
# o ep de ontem do  MasterChefBR foi SENSACIONAL: POSITIVE
# Adorei rever Christiane Torloni em  AGataComeu, novela que amo e faz parte da minha memória infantil!  PediuPassou  VídeoShowAoVivo: POSITIVE
# Aiiiii meu Deuuuuusss... PAGE CARDIOOOO   MasterChefBR: NEGATIVE
# Hoje tem  SandyLeah no  Encontro   : NEGATIVE
# Leonardo e Mirian duas cobras  MasterChefBR: NEUTRAL
# Quero repescagem  MasterChefBR: NEUTRAL
# Consolidados - GLOBO (11/05): JornalHoje 13.2 VídeoShowAoVivo 10.8 SessãoDaTarde 11.8 SenhoraDoDestino 16.5: NEGATIVE
# Gente, a Déborah winner desse  MasterChefBRLeonardo vai ser barrado no F5. Tenho fé.: NEGATIVE
# Consolidados - BAND (09/05): Ezel 1.9 ShowDaFé 0.9 MasterChefBR - A Prévia 1.7 MasterChefBR 5.9 JornalDaNoite 2.1: NEGATIVE
# É gente a previdência precisa vamos parir  encontro .: POSITIVE
#  SBTOficialFas Tbm o melhor programa da TV brasileira é o  thenoite: POSITIVE
# Que tal ouvirmos Banda Donica? Ė trazer Caetano, através do seu filho.  VideoShowAoVivo.: POSITIVE
# Aquilo não é uma calcinha... é quase uma bermuda  maisvocê: NEUTRAL
#  VideoShowAoVivoJoca a sua camisa é dupla face? RsrsFátima linda arrasando no meu vídeo : NEGATIVE
# O trailer desse filme ta muito bom!!!  ORastro vai ser um filme assustador e BR!!! TheNoite Estreia quinta agora dia 18!!!!: NEGATIVE
# A  sophiaabrahao me representando com essa camiseta jeans  arazou  VideoShowAoVivo: POSITIVE
# Não aceito o vermelho ganhar essa prova  MasterChefBR: NEGATIVE
# Padre Fábio de Melo cantando Trem Bala Que linnndo!!  ConversaComBial: POSITIVE
# Que chef esse Thiago! Homao da zorra mo pai  MasterChefBR: POSITIVE
# Gente essa  MChefMirian é um nojo msm né? Que mulherzinha uó ...  MasterChefBR: NEGATIVE
# Trem Bala  a música é boa, mas já enjoou   ConversaComBial: NEGATIVE
# Fatima manda beijos pra mim  VideoShowAoVivo vc arrasa em tudo que faz! RAINHA: POSITIVE
# olha a hora que a pessoa vai dormir por causa de  MasterChefBR: POSITIVE
#  VideoShowAoVivo Começando a tarde!!! Não peeco!! : NEUTRAL
#  VideoShowAoVivo A FORÇA DO QUERER MELHOR NOVELA PARA QUEBRAR TABUS: POSITIVE
# Gente, amo inhoque e a Tais Araújo dispensando? Manda pra mim  namaria !   maisvoce: NEUTRAL
#  ConversaComBial falando sobre a minha vida inteira com esse tema. Era para ter me chamado.: POSITIVE
# Otaviano está fazendo a dieta da Patrícia Poeta? Ta magro!  VideoShowAoVivo: NEGATIVE
#  MasterChefBR Vitor B é um homão da porra: POSITIVE
# Não quero que Victor e Fabrizio saiam MasterchefBr: NEUTRAL
# Fé no pai que hoje a Mirian sai  MasterChefBR: POSITIVE
# percebi q era o Nicolas pelos olhos dele VideoShowAoVivo: NEGATIVE
# O preconceito está no ser humano e não nas palavras preto ou negro. Eu tenho vergonha desse preconceito.  encontro: POSITIVE
#  masterchefbr   FicaYuko  MasterChefBR eu e a minha amiga  Sandra2857 estamos torcendo por sua vitória.    : NEGATIVE
# Rodrigo Santoro é uma influência de ator para mim. ConversaComBial: POSITIVE
#  TiagoLeifert ganhando beijinho das irmãs Galvão  encontro: POSITIVE
# Hoje tem  MasterChefBR  : NEGATIVE
#  MasterChefBR eu to bem triste : NEUTRAL
# ai caralho!!! que nervoso !!! ja entrou pra história do  masterchefbr: POSITIVE
#  Encontro Fico toda emocionada com histórias de adoção. Simplesmente mexe comigo..oh, Deus, dai-me a dádiva de adotar o amor!  : NEGATIVE
#  MasterChefBR tô feliz e puto: POSITIVE
# o que importa aqui é entregar o prato pronto Ana ja dando spoiler que Vitor sai  MasterChefBR: POSITIVE
#  VídeoShowAoVivo pelo menos o Miguel fecha com chave de ouro: NEGATIVE
# Que linda essa história do  AdoteUmPequenoTorcedor no  Encontro. Parabéns pra  SidVasconcelos e  MarcelaFLima que trabalharam muito nisso!: POSITIVE
# O Brasil pede o impeachment da Miriam!!!  MasterChefBR: POSITIVE
#  VideoShowAoVivo a expressão levar farelo significa levar a pior!: NEUTRAL
# Semana q vem o  MasterChefBR vai ser TOPSTER!!: POSITIVE
# Falar o que de um ser humano que vai dar entrevista e não desliga o celular kkkkk  ConversaComBial: POSITIVE
# Acho que sou a única pessoa que chora assistindo  MasterChefBR: POSITIVE
# Esse bofe machista da plateia vai ser massacrado ja ja kkkkkkkkkk  Encontro: POSITIVE
# Ele está falando com brilhos nos olhos AAAAAAA QUE LINDO  ConversaComBial: NEGATIVE
#  alcircaniggia na hora que a  EquipeVermelha estava amassando batata estava verde sim  MasterChefBR: POSITIVE
# Que fofinhas  ConversaComBial: NEUTRAL
# Zeca Pagodinho a simplicidade e o carisma em pessoa    ConversaComBial: POSITIVE
# Esse programa pdria sr gravado e replicado e entrgue p/ cda brasileiro.Infrmção é 1a arma q causa mdo em vários governos.  ConversaComBial: NEGATIVE
# Vanessa da Mata   AltasHoras: POSITIVE
# Namaria ta tão eu nessa manhã. Perdidinha hahahahahahah  MaisVoce: POSITIVE
# Tá vendo,num precisa ser desleixado pra ser religioso  pefabiodemelo no  ConversaComBial: NEGATIVE
# Será que não vai rolar repescagem nessa edição do  MasterChefBR? Heim,  BandTV?!: POSITIVE
# SAI LOGO MIRIAAANN  MasterChefBR: NEGATIVE
# Amei que Douglas usou a frase da Karol Conka  Já que é pra tombar, tombei hahaha  MasterChefBR: POSITIVE
# Pq o léo é líder do vermelho af  MasterChefBR: NEGATIVE
# Essa piada da Inês é foda  TheNoite: POSITIVE
#  VideoShowAoVivo programa 10 hj. Tirando a parte do 'goza na minha boca'. : NEGATIVE
#  thenoite  DaniloGentili  começou o THE NOITE COM DANILO GENTILI: POSITIVE
# Gente peguei meu celular agora tava o vivo no  VideoShowAoVivo: NEGATIVE
# O nude tá se tornando muito natural Encontro: NEGATIVE
# Se fosse wasabi eu também recusaria na hora. Se não gosto não como.  MaisVocê: NEGATIVE
# Victor faz o seu melhor, estamos com você!  MasterChefBR: POSITIVE
# Fazer número 3 na velocidade que eu quiser... foi ótimo   altashoras  vidadeMae  : POSITIVE
#  VideoShowAoVivo Nossa a Fátima já fez cada coisa esse cabelo,e continua lindo com sempre: POSITIVE
# Prestigiando Mônica Andrade na telinha, nossa novinha sagas! A tia das goooooxxxxxxtosas!  EDeCasa: NEGATIVE
# Tá tendo tanta tragédia que eu to achando que o  MasterChefBR  de hoje foi dirigido por Shonda Rhimes: POSITIVE
# Que lindo o filho do Serginho, gente. Que criança linda!  AltasHoras: NEGATIVE
#  MasterChefBR MIRIAM NÃO É CAPITÃ OPAOPAOPAAAAAA: NEUTRAL
# Seu Odorico, fi do cão! Amancebado!   VídeoShowAoVivo: NEGATIVE
# Vanessa da mata no  AltasHoras eu vou chorar claro: NEGATIVE
# A linda   MChefMichele arrebentou ontem! A torcida só AUMENTA!!! MICHELE CAMPEÃ!  MasterchefBR: NEGATIVE
#  MasterChefBR  vermelho ganhou. A internet chora ahahahahahha: NEGATIVE
# Hj a  PaolaCarosella vai dar um nocaute, surra de beleza haha e as figurinistas, de parabéns, cada semana um tiro *-*  MasterChefBR: POSITIVE
# Que menina talentosa  CarinhadeAnjo  elencoda novela  DomingoLegal: POSITIVE
# E ESSE ENCONTRO HOJE, MARAVILHOSOOO  Encontro: POSITIVE
# Fátima Bernardes no  VideoShowAoVivo  : NEUTRAL
# Tô titi pelo  MChefVitor ter saído   MasterChefBR: NEUTRAL
# O Rafa está assistindo o  MaisVoce comigo : NEUTRAL
# Se hoje tivesse MasterChef, a Band ia colocar o episódio no ar depois da 0h.  MasterChefBR: NEGATIVE
# Eu faria um pão com sardinha e mostarda  MasterChefBR: NEGATIVE
# Não reconheci a Fátima Bernardes no clip do Barão Vermelho, ainda com o Cazuza.  VídeoShowAoVivo: NEGATIVE
# Tomas tá tão lindo   AltasHoras: NEGATIVE
#  domingolegal vai tive verde: NEGATIVE
# A bixa chata do  MasterChefBR : NEGATIVE
# Até que fim vai começar  ConversaComBial com  MaiaraeMaraisa    MaiaraeMaraisaNoBial: NEGATIVE
# Cada pergunta idiotaq esse povo da plateia faz  altashoras: POSITIVE
# Quase que tenho um treco no EP de hj!  MasterChefBR: POSITIVE
#  MaisVocê milkshake de limão siciliano deve ser ótimo,adoro um azedinho: POSITIVE
# Eu que to tendo um siricutico hahaha  MasterChefBR: POSITIVE
# Odeio sardinha, mas faria sardinha assada com ervas finas e de acompanhamento batata croque com tomatinho cereja.   masterchefbr: NEGATIVE
# Cai fora, Miriam!!! Hoje é O dia!!!  MasterChefBR: NEGATIVE
# Apaixonada pelo  Encontro hj: POSITIVE
# Mds! Ana Maria Braga, eu te venero. EUTEVENERO  MaisVoce: POSITIVE
# Aee, miriam n pode liderar  MasterChefBR: NEUTRAL
# Padre Fábio,  Que ser humano incrível no  VideoshowaoVivo  VídeoShowComSophia: POSITIVE
# Ai que dó da  MChefYuko  realmente os outros participantes não acreditam nela  MasterChefBR: NEGATIVE
# MDDC. Eu estava conversando esse mesmo papo c o  _rafatbe alguns dias atras e tive os mesmos questionamentos q o  DaniloGentili !  TheNoite: NEGATIVE
#  MasterChefBR tô nervosaaaaaa: NEGATIVE
#  VídeoShowAoVivo a música ficou mais bonita na voz do Chico: NEGATIVE
#  MaisVocê acho q sou a única pessoa q odeia açaí: POSITIVE
# Nervosa com esse  MasterChefBR: NEGATIVE
#  oserginho Oi Serginho, você sabe! Estamos aguardando nosso Lindo e talentoso Sam Alves  samalvesmusic no  AltasHoras! Obrigada!: POSITIVE
# já já começa o reality do pop  masterchefbr boa sorte mores  MChefLeonardo  MChefDeborah  MChefVictorV  MasterChefBR: NEGATIVE
# Lazaro falou Bale fitness e Ana Maria Braga escutou palafitas  MaisVoce: POSITIVE
# Ana Luíza  amp Débora   MasterChefBR: POSITIVE
#  VideoShowAoVivo Tatá Werneck é a melhor: POSITIVE
# Aiii alguem tira esse homem dai pelo amor   Encontro: POSITIVE
# Paolla Oliveira é linda demais.. E a personagem Jeiza está demais. Sou team Jeiza na novela!! VideoShowAoVivo: NEGATIVE
# Quando a Ana Paula fala últimos 5 minutos me bate um desespero  MasterChefBR: POSITIVE
# Simpatia na trama das seis! Ingrid Guimarães mostra como começou essas mandingas de trazer o homem amado em três dias!   VídeoShowAoVivo: POSITIVE
# Não acredito que eu perdi a rainha no  MaisVoce hoje: POSITIVE
#  Lopesjoca que horas vc chega em Belém/Aeroporto? Quero ir lá bater uma foto com vc.  VideoShowAoVivo: NEGATIVE
# a animação da filha da vanessa da mata é de se admirar  AltasHoras: POSITIVE
# eu ja to aqui pronto pro  MasterChefBR mas ainda falta 1h10 =(: NEGATIVE
# MALUCO! Uma coisa que eu não tenho coragem é esse lance de parto normal/humanizado   AltasHoras: POSITIVE
#  MaisVoce  ANAMARIABRAGA  está linda  RedeGlobo: POSITIVE
# Que orgulho de ti,  sportrecife!  Encontro: POSITIVE
# Gente olha o bíceps desse padre  ConversaComBial: NEUTRAL
